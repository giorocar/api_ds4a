# %% [markdown]
# ### Análisis preliminar Dataset SECOP por Flor Milena Vela S.

# %%
import pandas as pd

# %% [markdown]
# ### SECOP_I_Contratos: Son 72 columnas

# %%
# Explorando los datos
SECOPI_df = pd.read_csv("datos/SECOP_I_Contratos.csv", nrows=1000)
print(SECOPI_df.columns)
print(SECOPI_df.info())
SECOPI_df.head(2)
# Out:
# Index(['UID', 'Anno Cargue SECOP', 'Anno Firma del Contrato', 'Nivel Entidad',
#        'Orden Entidad', 'Nombre de la Entidad', 'NIT de la Entidad',
#        'Código de la Entidad', 'ID Tipo de Proceso', 'Tipo de Proceso',
#        'Estado del Proceso', 'Causal de Otras Formas de Contratacion Directa',
#        'ID Regimen de Contratacion', 'Regimen de Contratacion',
#        'ID Objeto a Contratar', 'Objeto a Contratar',
#        'Detalle del Objeto a Contratar', 'Tipo de Contrato',
#        'Municipio Obtencion', 'Municipio Entrega', 'Municipios Ejecucion',
#        'Fecha de Cargue en el SECOP', 'Numero de Constancia',
#        'Numero de Proceso', 'Numero del Contrato', 'Cuantia Proceso',
#        'ID Grupo', 'Nombre Grupo', 'ID Familia', 'Nombre Familia', 'ID Clase',
#        'Nombre Clase', 'ID Ajudicacion', 'Tipo Identifi del Contratista',
#        'Identificacion del Contratista', 'Nom Raz Social Contratista',
# ...

# %% [markdown]
# ### SECOP_II_Contratos: Son 54 columnas y diferentes

# %%
# Explorando los datos
SECOP2_df = pd.read_csv("datos/SECOP_II_Contratos.csv", nrows=1000)
print(SECOP2_df.columns)
print(SECOP2_df.info())
SECOP2_df.head()
# Out:
# Index(['Nombre Entidad', 'Nit Entidad', 'Departamento', 'Ciudad',
#        'Localización', 'Orden', 'Sector', 'Rama', 'Entidad Centralizada',
#        'Proceso de Compra', 'ID Contrato', 'Referencia del Contrato',
#        'Estado Contrato', 'Codigo de Categoria Principal',
#        'Descripcion del Proceso', 'Tipo de Contrato',
#        'Modalidad de Contratacion', 'Justificacion Modalidad de Contratacion',
#        'Fecha de Firma', 'Fecha de Inicio del Contrato',
#        'Fecha de Fin del Contrato', 'Fecha de Inicio de Ejecucion',
#        'Fecha de Fin de Ejecucion', 'Condiciones de Entrega',
#        'TipoDocProveedor', 'Documento Proveedor', 'Proveedor Adjudicado',
#        'Es Grupo', 'Es Pyme', 'Habilita Pago Adelantado', 'Liquidación',
#        'Obligación Ambiental', 'Obligaciones Postconsumo', 'Reversion',
#        'Valor del Contrato', 'Valor de pago adelantado', 'Valor Facturado',
#        'Valor Pendiente de Pago', 'Valor Pagado', 'Valor Amortizado',
# ...

# %%
SECOP2_df['URLProceso']

# %% [markdown]
# ### Muestra de 100K SECOP-I

# %%
SECOPI_df = pd.read_csv("datos/secop1_sample_100K.csv")
##print(SECOPI_df.columns)
##print(SECOPI_df.info())
len(SECOPI_df)
# Out:
# 100010

# %%
SECOPI_df.describe().transpose()
# Out:
#                                  count          mean           std  \
# Anno Cargue SECOP             100010.0  2.016004e+03  2.698808e+00
# Anno Firma del Contrato       100010.0  1.745248e+03  6.876661e+02
# Código de la Entidad          100010.0  1.877516e+08  8.343506e+07
# ID Tipo de Proceso            100010.0  9.822378e+00  3.813479e+00
# ID Regimen de Contratacion    100008.0  2.722752e+00  4.486016e-01
# ID Objeto a Contratar         100010.0  7.396550e+07  1.770959e+07
# Cuantia Proceso               100010.0  4.434912e+08  8.030329e+10
# ID Familia                    100010.0  4.965946e+03  3.798228e+03
# ID Clase                      100010.0  4.966059e+05  3.798299e+05
# ID Ajudicacion                100010.0  4.698679e+06  3.137249e+06
# Plazo de Ejec del Contrato    100010.0  4.803964e+01  1.110141e+02
# Tiempo Adiciones en Dias      100010.0  2.648215e+00  2.174512e+01
# Tiempo Adiciones en Meses     100010.0  1.077392e-01  1.450535e+00
# ...

# %%
SECOPI_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100010 entries, 0 to 100009
# Data columns (total 72 columns):
#  #   Column                                          Non-Null Count   Dtype
# ---  ------                                          --------------   -----
#  0   UID                                             100010 non-null  object
#  1   Anno Cargue SECOP                               100010 non-null  int64
#  2   Anno Firma del Contrato                         100010 non-null  int64
#  3   Nivel Entidad                                   100010 non-null  object
#  4   Orden Entidad                                   100010 non-null  object
#  5   Nombre de la Entidad                            100010 non-null  object
#  6   NIT de la Entidad                               100010 non-null  object
#  7   Código de la Entidad                            100010 non-null  int64
#  8   ID Tipo de Proceso                              100010 non-null  int64
# ...

# %% [markdown]
# ### Muestra de 100K SECOP-II

# %%
SECOPII_df = pd.read_csv("datos/secop2_sample_100K.csv")
##print(SECOPI_df.columns)
##print(SECOPI_df.info())
len(SECOPII_df)
# Out:
# 100000

# %%
SECOPII_df.describe().transpose()
# Out:
#                                     count          mean           std  \
# Nit Entidad                      100000.0  1.751807e+09  2.502078e+09
# Valor del Contrato               100000.0  3.681377e+11  4.531432e+13
# Valor de pago adelantado         100000.0  1.275391e+06  1.359823e+08
# Valor Facturado                  100000.0  1.715370e+07  3.875547e+08
# Valor Pendiente de Pago          100000.0  1.945067e+08  5.677152e+09
# Valor Pagado                     100000.0  1.344669e+07  3.592255e+08
# Valor Amortizado                 100000.0  3.153334e+04  4.327126e+06
# Valor Pendiente de Amortizacion  100000.0  1.243857e+06  1.359052e+08
# Valor Pendiente de Ejecucion     100000.0  1.941373e+08  5.686505e+09
# Saldo CDP                        100000.0  6.947951e+09  1.550249e+11
# Saldo Vigencia                   100000.0  1.765379e+09  3.543066e+10
# Días Adicionados                 100000.0  5.597330e+00  2.577934e+01
#
# ...

# %%
SECOPII_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 54 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Nombre Entidad                           100000 non-null  object
#  1   Nit Entidad                              100000 non-null  int64
#  2   Departamento                             100000 non-null  object
#  3   Ciudad                                   100000 non-null  object
#  4   Localización                             100000 non-null  object
#  5   Orden                                    100000 non-null  object
#  6   Sector                                   100000 non-null  object
#  7   Rama                                     100000 non-null  object
#  8   Entidad Centralizada                     100000 non-null  object
#  9   Proceso de Compra                        100000 non-null  object
# ...

# %%
SECOPII_df.columns
SECOPII_df['Orden'].unique()
SECOPII_df['Codigo de Categoria Principal'].nunique()
filt_df = SECOPII_df[SECOPI_df['Cuantia Proceso']<SECOPI_df['Valor Contrato con Adiciones']]
filt_df.loc[:,['Cuantia Proceso','Valor Contrato con Adiciones']]
#filt_df
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-085758f23302> in <module>
#       3 SECOPII_df['Codigo de Categoria Principal'].nunique()
#       4 filt_df = SECOPII_df[SECOPI_df['Cuantia Proceso']<SECOPI_df['Valor Contrato con Adiciones']]
# ----> 5 filt_df.loc[:,['Cuantia Proceso','Valor Contrato con Adiciones']]
#       6 #filt_df
#       7
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
# ...

# %%
SECOPII_df['Codigo de Categoria Principal'].unique()
# Out:
# array(['V1.93141500', 'V1.80111600', 'V1.46191600', ..., 'V1.76111506',
#        'V1.81111506', 'V1.83121702'], dtype=object)

# %%
SECOPI_df.columns
SECOPI_df['Orden Entidad'].unique()
# Out:
# array(['TERRITORIAL DEPARTAMENTAL DESCENTRALIZADO',
#        'TERRITORIAL DEPARTAMENTAL CENTRALIZADO',
#        'TERRITORIAL DISTRITAL MUNICIPAL NIVEL 3',
#        'NACIONAL DESCENTRALIZADO',
#        'TERRITORIAL DISTRITAL MUNICIPAL NIVEL 5', 'NACIONAL CENTRALIZADO',
#        'TERRITORIAL DISTRITAL MUNICIPAL NIVEL 4',
#        'TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6',
#        'TERRITORIAL DISTRITAL MUNICIPAL NIVEL 2', 'DISTRITO CAPITAL',
#        'TERRITORIAL DISTRITAL MUNICIPAL NIVEL 1', 'No Definido'],
#       dtype=object)
